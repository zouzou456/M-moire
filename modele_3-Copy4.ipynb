# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_log_error
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Chargement des données
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
oil = pd.read_csv("oil.csv")
holidays = pd.read_csv("holidays_events.csv")
stores = pd.read_csv("stores.csv")

# %%
train
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3000883  3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# ...

# %%
len(train)
# Out:
# 3000888

# %%
train['sales'].mean()
# Out:
# 357.77574911262707

# %%
test
# Out:
#             id        date  store_nbr                      family  onpromotion
# 0      3000888  2017-08-16          1                  AUTOMOTIVE            0
# 1      3000889  2017-08-16          1                   BABY CARE            0
# 2      3000890  2017-08-16          1                      BEAUTY            2
# 3      3000891  2017-08-16          1                   BEVERAGES           20
# 4      3000892  2017-08-16          1                       BOOKS            0
# ...        ...         ...        ...                         ...          ...
# 28507  3029395  2017-08-31          9                     POULTRY            1
# 28508  3029396  2017-08-31          9              PREPARED FOODS            0
# 28509  3029397  2017-08-31          9                     PRODUCE            1
# 28510  3029398  2017-08-31          9  SCHOOL AND OFFICE SUPPLIES            9
# 28511  3029399  2017-08-31          9                     SEAFOOD            0
#
# ...

# %%
oil
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
holidays
# Out:
#            date        type    locale locale_name  \
# 0    2012-03-02     Holiday     Local       Manta
# 1    2012-04-01     Holiday  Regional    Cotopaxi
# 2    2012-04-12     Holiday     Local      Cuenca
# 3    2012-04-14     Holiday     Local    Libertad
# 4    2012-04-21     Holiday     Local    Riobamba
# ..          ...         ...       ...         ...
# 345  2017-12-22  Additional  National     Ecuador
# 346  2017-12-23  Additional  National     Ecuador
# 347  2017-12-24  Additional  National     Ecuador
# 348  2017-12-25     Holiday  National     Ecuador
# 349  2017-12-26  Additional  National     Ecuador
#
#                        description  transferred
# 0               Fundacion de Manta        False
# 1    Provincializacion de Cotopaxi        False
# 2              Fundacion de Cuenca        False
# 3        Cantonizacion de Libertad        False
# 4        Cantonizacion de Riobamba        False
# ..                             ...          ...
# ...

# %%
stores
# Out:
#     store_nbr           city                           state type  cluster
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# ...

# %%
# Feature engineering
train['year'] = pd.to_datetime(train['date']).dt.year
train['month'] = pd.to_datetime(train['date']).dt.month
train['day'] = pd.to_datetime(train['date']).dt.day

# %%
train
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3000883  3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887  2017-08-15          9                     SEAFOOD    16.000
#
# ...

# %%
# Gestion des valeurs manquantes
# Vérifier les valeurs manquantes dans l'ensemble de données d'entraînement
missing_values_train = train.isnull().sum()

#Vérifier les valeurs manquantes dans l'ensemble de données de test
missing_values_test = test.isnull().sum()

print("Missing values in the train dataset:")
print(missing_values_train)

print("\nMissing values in the test dataset:")
print(missing_values_test)
# Out:
# Missing values in the train dataset:
# id             0
# date           0
# store_nbr      0
# family         0
# sales          0
# onpromotion    0
# year           0
# month          0
# day            0
# dtype: int64
#
# Missing values in the test dataset:
# id             0
# date           0
# store_nbr      0
# family         0
# onpromotion    0
# dtype: int64

# %%
# remplissage des emplacement manquants avec la valeur moyenne
train['sales'].fillna(train['sales'].mean(), inplace=True)
oil['dcoilwtico'].fillna(oil['dcoilwtico'].mean(), inplace=True)
test['onpromotion'].fillna(test['onpromotion'].mean(), inplace=True)

# %%
sum(oil['dcoilwtico'].isna() == True)
# Out:
# 0

# %%
# Traitement holidays and events
train['is_holiday'] = train['date'].isin(holidays['date'])
test['is_holiday'] = test['date'].isin(holidays['date'])

# Traitement oil prices
train = train.merge(oil, on='date', how='left')
test = test.merge(oil, on='date', how='left')

train.drop(['date', 'id'], axis = 1,inplace = True)

# %%
#train['dcoilwtico'].fillna(train['dcoilwtico'].mean(), inplace=True)
sum(train['dcoilwtico'].isna() == True)
# Out:
# 857142

# %%
train
# Out:
#          store_nbr                      family     sales  onpromotion  year  \
# 0                1                  AUTOMOTIVE     0.000            0  2013
# 1                1                   BABY CARE     0.000            0  2013
# 2                1                      BEAUTY     0.000            0  2013
# 3                1                   BEVERAGES     0.000            0  2013
# 4                1                       BOOKS     0.000            0  2013
# ...            ...                         ...       ...          ...   ...
# 3000883          9                     POULTRY   438.133            0  2017
# 3000884          9              PREPARED FOODS   154.553            1  2017
# 3000885          9                     PRODUCE  2419.729          148  2017
# 3000886          9  SCHOOL AND OFFICE SUPPLIES   121.000            8  2017
# 3000887          9                     SEAFOOD    16.000            0  2017
#
#          month  day  is_holiday  dcoilwtico
# ...

# %%
3000888*80/100
# Out:
# 2400710.4

# %%
train_avec = train.drop(['family'], axis = 1)
train_sans = train.drop(['store_nbr', 'family'], axis = 1)

X_train_a = train_avec.drop(['sales'], axis = 1).values[:2400710]
X_test_a = train_avec.drop(['sales'], axis = 1).values[2400710:]
y_train_a = train_avec['sales'].values[:2400710]
y_test_a = train_avec['sales'].values[2400710:]
# X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(train_sans.drop(['sales'], axis = 1).values, train_sans['sales'].values, test_size=0.2, random_state=42)

# Modèle de Random Forest
model_a = RandomForestRegressor(n_estimators=10, random_state=42)
model_a.fit(X_train_a, y_train_a)


from sklearn.metrics import mean_squared_error
# Évaluation du modèle

y_pred_sur_lui_meme = model_a.predict(X_train_a)
y_pred = model_a.predict(X_test_a)
print(f'Mean Squared Error sur lui-même avec store_nbr : {mean_squared_error(y_train_a, y_pred_sur_lui_meme)}')
print(f"Mean Squared Error sur le test avec store_nbr : {mean_squared_error(y_test_a, y_pred)}")


# print()

# # Modèle de Random Forest
# model_s = RandomForestRegressor(n_estimators=5, random_state=42)
# model_s.fit(X_train_s, y_train_s)

# # Évaluation du modèle
# print(f"Accuracy sur lui-même sans store_nbr : {model_s.score(X_train_s, y_train_s)}")
# print(f"Accuracy sur le test sans store_nbr : {model_s.score(X_test_s, y_test_s)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10941/1287512016.py in <module>
#      10 # Modèle de Random Forest
#      11 model_a = RandomForestRegressor(n_estimators=10, random_state=42)
# ---> 12 model_a.fit(X_train_a, y_train_a)
#      13
#      14
#
# ~/.local/lib/python3.10/site-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# ~/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     346         if issparse(y):
#     347             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 348         X, y = self._validate_data(
# ...

# %%
# Tracé des résultats sur train
plt.figure(figsize=(12, 6))
plt.plot(range(0, len(y_train_a)), y_train_a, label='True Values', marker='o')
plt.plot(range(0, len(y_train_a)), y_pred_sur_lui_meme, label='Predictions', marker='o')
plt.title('Prédictions avec Random Forest')
plt.xlabel('Date')
plt.ylabel('Valeur')
plt.legend()
plt.show()

# %%
# Tracé des résultats sur test
plt.figure(figsize=(12, 6))
plt.plot(range(0, len(y_test_a)), y_test_a, label='True Values', marker='o')
plt.plot(range(0, len(y_test_a)), y_pred, label='Predictions', marker='o')
plt.title('Prédictions avec Random Forest')
plt.xlabel('Date')
plt.ylabel('Valeur')
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_a)
X_test_scaled = scaler.transform(X_test_a)

# Modèle de Random Forest
model_scaled = RandomForestRegressor(n_estimators=10, random_state=42)
model_scaled.fit(X_train_scaled, y_train_a)

# Évaluation du modèle
print(f"Accuracy sur lui-même avec store_nbr : {model_a.score(X_train_scaled, y_train_a)}")
print(f"Accuracy sur le test avec store_nbr : {model_a.score(X_test_scaled, y_test_a)}")
# Out:
# Accuracy sur lui-même avec store_nbr : 0.0901795198248867
# Accuracy sur le test avec store_nbr : 0.08853244575788588

# %%
X_train_scaled[0]
# Out:
# array([ 1.12281663, -0.04932238,  1.6073284 , -0.06134829,  0.61091494,
#        -0.41944325, -1.19230127])

# %%
X_test_scaled[0]
# Out:
# array([ 1.18697628,  4.77596258,  0.8639858 ,  1.12004873,  1.4069459 ,
#        -0.41944325, -0.89977993])

# %%
#split Train-validation
train_data, val_data = train_test_split(train, test_size=0.2, random_state=42)

# %%
features = [
    'dcoilwtico',
    'store_nbr',
    'onpromotion',
]

target = 'sales'

# %%
print(train_data.columns)
# Out:
# Index(['id', 'date', 'store_nbr', 'family', 'sales', 'onpromotion', 'year',
#        'month', 'day', 'is_holiday', 'dcoilwtico'],
#       dtype='object')

# %%
# Modèle de Random Forest
model = RandomForestRegressor(n_estimators=5, random_state=42)
model.fit(train_data[features], train_data[target])
# Out:
# RandomForestRegressor(n_estimators=5, random_state=42)

# %%
# predictions sur le set de validation
val_predictions = model.predict(val_data[features])
val_predictions
# Out:
# array([3384.22699719,    3.88914956,  638.15304083, ...,  112.80606931,
#         596.12398745, 1013.24094619])

# %%
# Calcul RMSLE
rmsle = np.sqrt(mean_squared_log_error(val_data[target], val_predictions))
print(f"Root Mean Squared Logarithmic Error (RMSLE): {rmsle}")
# Out:
# Root Mean Squared Logarithmic Error (RMSLE): 3.175003909535403

# %%
print(test.columns)
# Out:
# Index(['id', 'date', 'store_nbr', 'family', 'onpromotion', 'is_holiday',
#        'dcoilwtico'],
#       dtype='object')

# %%
# predictions sur le set de test
test_predictions = model.predict(test[features])
print(test_predictions)
# Out:
# [ 127.31004014  127.31004014  418.71649014 ...  574.70337613 1368.00226618
#   217.64331721]

# %%
# Création d'un fichier submission
submission = pd.DataFrame({'id': test['id'], 'unit_sales': test_predictions})

# %%
import numpy as np
import matplotlib.pyplot as plt

def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
    plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
    for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
            ax = plt.subplot(1, len(colname_pairs), plot_i)
            df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
            ax.spines[['top', 'right',]].set_visible(False)
    plt.tight_layout()
    plt.show()

chart = scatter_plots(submission, *[[['id', 'unit_sales']]], **{})
chart

# %%
import seaborn as sns
sns.distplot(submission['unit_sales'], bins=800, kde=False)
plt.title('unit_sales')
plt.xlabel('Vente des unités')
plt.ylabel('Fréquence')
plt.xlim(0, 700)
plt.ylim(0, 4500)
plt.show()
# Out:
# c:\Users\chens\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
hist, bins = np.histogram(submission['unit_sales'], bins=500)
plt.bar(bins[:-1], hist, width=(bins[1]-bins[0]))
plt.title('unit_sales')
plt.xlabel('Vente des unités')
plt.ylabel('Fréquence')
plt.xlim(0, 700)
plt.ylim(0, 4500)
plt.show()

# %%
submission.to_csv('submission.csv', index=False)
